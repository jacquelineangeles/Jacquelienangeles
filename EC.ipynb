# %% [markdown]
# <a href="https://colab.research.google.com/github/jacquelineangeles/Jacquelienangeles/blob/main/EC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extra Credit

# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 265.1
AUD1_MEAN = 235.9
VIS1_STD = 30.72
AUD1_STD = 42.51

# %%
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')
